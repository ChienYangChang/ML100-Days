# %%
""" 
作業1：

請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：


1. 你選的這組資料為何重要
-  透過父母教育的程度對學生分數之影響

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
-  Kaggle-datasets, https://www.kaggle.com/spscientist/students-performance-in-exams

3. 蒐集而來的資料型態為何
-  表格{genderaaa, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score}

4. 這組資料想解決的問題如何評估
-  資料視覺化、平均值、線性迴歸...等
   可參考https://public.tableau.com/profile/yakov.gavrilov#!/vizhome/JacobGavrilovStudentDataAnalysis/Story1?publish=yes

"""

# %%
""" 
作業2：

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：


1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
-  有幾種方案
             A. 提高短程載客量，而非長程載客量，要確保永遠都能立刻有下一組客人，累積起來相當可觀 (因為起程基本收費)
             B. 提高長程"伴遊"載客，尋找旅客並提供專屬司機的服務
             C. 收集每日的熱區、特定活動區域…等
             D. 針對熟客提供長期合作優惠、儲值…等
             E. 提升服務品質(例如免費飲料、電視等)，絕對不能像"路上的小黃"一樣

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
-  透過車隊接客的記錄，可能來自於app、電話叫車、車上定位記錄等，客戶每次乘車的反饋記錄

3. 蒐集而來的資料型態為何
-  結構化的表格

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
-  分析資料視覺化，k-means分群等，了解主要客群的行為模式
   興利: 派車至每日的熱區、特定活動區域，根據歷史資料了解客戶喜好的原因，針對該項目進行加強
   除弊: 根據投訴電話，了解最常被投訴的類別、司機，進行教育課程

"""

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.306

# %%
#作業3：
#請點選檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#資料夾結構建立規則提醒：ML100 > data資料夾 & ipynb檔 
#(請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

import numpy as np
import matplotlib.pyplot as plt

def mean_squared_error(y, yp):
    ax = 1
    #mse = (np.square(y - yp)).mean(axis=None)
    mse = np.mean((y - yp)**2)
    return mse
    
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 219.404
# The Mean absolute error is 11.728
